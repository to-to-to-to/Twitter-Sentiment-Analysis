# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("pekanbaru.csv")
df.head()
# Out:
#                        created_at  ...                                           tweet_en
# 0  Fri Apr 03 08:30:02 +0000 2015  ...  #berita To the Pekanbaru City Health Office He...
# 1  Mon Sep 09 04:02:35 +0000 2019  ...  The smog was very thick and covered the city o...
# 2  Wed Jan 10 11:09:08 +0000 2018  ...  https://t.co/zfmclHoLR8 3 Doctors of Pekanbaru...
# 3  Mon Apr 29 15:07:27 +0000 2013  ...  A good and cheap dentist in the city of Pekanb...
# 4  Sun Oct 02 12:30:38 +0000 2016  ...  PEKANBARU - Achievement of the Human Developme...
#
# [5 rows x 3 columns]

# %%
def cleanTxt(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text)
    text = re.sub(r'#', '', text)
    text = re.sub(r'RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/\S+', '', text)
    
    return text

df['tweet_en'] = df['tweet_en'].apply(cleanTxt)
df['text'] = df['text'].apply(cleanTxt)
df
# Out:
#                          created_at  ...                                           tweet_en
# 0    Fri Apr 03 08:30:02 +0000 2015  ...  berita To the Pekanbaru City Health Office Hel...
# 1    Mon Sep 09 04:02:35 +0000 2019  ...  The smog was very thick and covered the city o...
# 2    Wed Jan 10 11:09:08 +0000 2018  ...   3 Doctors of Pekanbaru Regional Hospital are ...
# 3    Mon Apr 29 15:07:27 +0000 2013  ...  A good and cheap dentist in the city of Pekanb...
# 4    Sun Oct 02 12:30:38 +0000 2016  ...  PEKANBARU - Achievement of the Human Developme...
# ..                              ...  ...                                                ...
# 381  Mon May 07 16:45:55 +0000 2018  ...  Pekanbaru City has several hospitals that are ...
# 382  Tue Apr 24 14:53:31 +0000 2018  ...  Tengku Rafian Siak Hospital Towards SNARS Accr...
# 383  Sat Sep 20 04:19:26 +0000 2014  ...  Last day! Ã ¢ Â € Â ”at Puskesmas Harapan Raya...
# 384  Mon Nov 24 03:32:29 +0000 2014  ...  _Pekanbaru: Wrestling with Motorcycle Gangs, C...
# 385  Tue Mar 11 21:56:42 +0000 2014  ...  Pekanbaru Outbreaks of haze-induced diseases: ...
#
# [386 rows x 3 columns]

# %%
#mendapatkan subjectivity dan polarity
def getSubjectivity(text):
    c = str(text)
    return TextBlob(c).sentiment.subjectivity

def getPolarity(text):
    c = str(text)
    return TextBlob(c).sentiment.polarity

df['Subjectivity'] = df['tweet_en'].apply(getSubjectivity)
df['Polarity'] = df['tweet_en'].apply(getPolarity)

# %%
df
# Out:
#                          created_at  ... Polarity
# 0    Fri Apr 03 08:30:02 +0000 2015  ...    0.200
# 1    Mon Sep 09 04:02:35 +0000 2019  ...   -0.455
# 2    Wed Jan 10 11:09:08 +0000 2018  ...    0.000
# 3    Mon Apr 29 15:07:27 +0000 2013  ...    0.550
# 4    Sun Oct 02 12:30:38 +0000 2016  ...    0.000
# ..                              ...  ...      ...
# 381  Mon May 07 16:45:55 +0000 2018  ...    0.000
# 382  Tue Apr 24 14:53:31 +0000 2018  ...    0.000
# 383  Sat Sep 20 04:19:26 +0000 2014  ...    0.000
# 384  Mon Nov 24 03:32:29 +0000 2014  ...    0.000
# 385  Tue Mar 11 21:56:42 +0000 2014  ...    0.000
#
# [386 rows x 5 columns]

# %%
#wordcloud
allwords = ' '.join([twts for twts in df['tweet_en']])
wordCloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords)

plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
#mendapatkan nilai sentimen
def getAnalysis(score):
    if score < 0 :
        return 'Negative'
    elif score == 0 :
        return 'Neutral'
    else :
        return 'Positive'

df['Sentiment'] = df['Polarity'].apply(getAnalysis)

df
# Out:
#                          created_at  ... Sentiment
# 0    Fri Apr 03 08:30:02 +0000 2015  ...  Positive
# 1    Mon Sep 09 04:02:35 +0000 2019  ...  Negative
# 2    Wed Jan 10 11:09:08 +0000 2018  ...   Neutral
# 3    Mon Apr 29 15:07:27 +0000 2013  ...  Positive
# 4    Sun Oct 02 12:30:38 +0000 2016  ...   Neutral
# ..                              ...  ...       ...
# 381  Mon May 07 16:45:55 +0000 2018  ...   Neutral
# 382  Tue Apr 24 14:53:31 +0000 2018  ...   Neutral
# 383  Sat Sep 20 04:19:26 +0000 2014  ...   Neutral
# 384  Mon Nov 24 03:32:29 +0000 2014  ...   Neutral
# 385  Tue Mar 11 21:56:42 +0000 2014  ...   Neutral
#
# [386 rows x 6 columns]

# %%
#plot the polarity and subjectivity
plt.figure(figsize =(8,6))
for i in range (0, df.shape[0]):
    plt.scatter(df['Polarity'][i], df['Subjectivity'][i], color = 'Blue')

plt.title("Sentiment Analysis Pekanbaru")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.show()

# %%
#Plot the sentiment
df['Sentiment'].value_counts()

plt.title("Sentiment Analysis Pekanbaru")
plt.xlabel("Sentiment")
plt.ylabel("Counts")
df['Sentiment'].value_counts().plot(kind = "bar")
plt.show()

# %%
df_final = df[['created_at', 'text', 'Subjectivity', 'Polarity', 'Sentiment']]
df_final
# Out:
#                          created_at  ... Sentiment
# 0    Fri Apr 03 08:30:02 +0000 2015  ...  Positive
# 1    Mon Sep 09 04:02:35 +0000 2019  ...  Negative
# 2    Wed Jan 10 11:09:08 +0000 2018  ...   Neutral
# 3    Mon Apr 29 15:07:27 +0000 2013  ...  Positive
# 4    Sun Oct 02 12:30:38 +0000 2016  ...   Neutral
# ..                              ...  ...       ...
# 381  Mon May 07 16:45:55 +0000 2018  ...   Neutral
# 382  Tue Apr 24 14:53:31 +0000 2018  ...   Neutral
# 383  Sat Sep 20 04:19:26 +0000 2014  ...   Neutral
# 384  Mon Nov 24 03:32:29 +0000 2014  ...   Neutral
# 385  Tue Mar 11 21:56:42 +0000 2014  ...   Neutral
#
# [386 rows x 5 columns]

# %%
df_final.to_csv("sentiment_pekanbaru.csv")
