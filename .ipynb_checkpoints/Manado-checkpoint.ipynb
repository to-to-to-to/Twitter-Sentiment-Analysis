# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("datasets train/manado.csv")

# %%
df.head()
# Out:
#                        created_at  \
# 0  Tue Jul 14 06:01:38 +0000 2020
# 1  Thu Feb 07 14:24:19 +0000 2019
# 2  Fri Aug 16 14:51:25 +0000 2013
# 3  Fri Feb 03 15:50:38 +0000 2017
# 4  Fri Jan 27 15:23:38 +0000 2017
#
#                                                 text  \
# 0  Kota Manado yang ku cintai Kita nyanda mo lupa...
# 1  DBD Makan Korban, Perindo Giatkan Fogging di K...
# 2  Segera Hadir di Kota Manado "Kursus Estetika A...
# 3  Data Resmi Rumah Sakit di Kota Manado Provinsi...
# 4  Data Resmi Puskesmas di Kota Manado Provinsi S...
#
#                                             tweet_en
# 0  The city of Manado, which I love We love to fo...
# 1  DHF Eats Victims, Perindo Activates Fogging in...
# 2  Coming Soon in Manado City "All In One Aesthet...
# 3  Official Data for Hospitals in Manado City, No...
# 4  Official Data of Puskesmas in Manado City, Nor...

# %%
def getSubjectivity(text):
    c = str(text)
    return TextBlob(c).sentiment.subjectivity

def getPolarity(text):
    c = str(text)
    return TextBlob(c).sentiment.polarity

df['Subjectivity'] = df['tweet_en'].apply(getSubjectivity)
df['Polarity'] = df['tweet_en'].apply(getPolarity)

# %%
df
# Out:
#                          created_at  \
# 0    Tue Jul 14 06:01:38 +0000 2020
# 1    Thu Feb 07 14:24:19 +0000 2019
# 2    Fri Aug 16 14:51:25 +0000 2013
# 3    Fri Feb 03 15:50:38 +0000 2017
# 4    Fri Jan 27 15:23:38 +0000 2017
# ..                              ...
# 107  Fri May 17 08:11:47 +0000 2013
# 108  Wed Aug 07 01:33:05 +0000 2013
# 109  Sat Oct 05 23:34:13 +0000 2019
# 110  Tue Feb 12 16:22:36 +0000 2019
# 111  Tue Jul 14 07:10:06 +0000 2015
#
#                                                   text  \
# 0    Kota Manado yang ku cintai Kita nyanda mo lupa...
# 1    DBD Makan Korban, Perindo Giatkan Fogging di K...
# 2    Segera Hadir di Kota Manado "Kursus Estetika A...
# 3    Data Resmi Rumah Sakit di Kota Manado Provinsi...
# 4    Data Resmi Puskesmas di Kota Manado Provinsi S...
# ..                                                 ...
# 107  Kota Manado Juara I Kinerja Program Jaminan Ke...
# 108  I'm at RSUD Prof. DR. Dr. Kandou Malalayang (K...
# 109  Kamis (03/10/2019) di Aula Sam Ratulangi Lanta...
# 110  Warga Sambut Antusias Periksa Kesehatan Gratis...
# 111  HBD kota manado,,,panjang umur deng sehat seha...
#
#                                               tweet_en  Subjectivity  Polarity
# 0    The city of Manado, which I love We love to fo...      0.575000  0.475000
# 1    DHF Eats Victims, Perindo Activates Fogging in...      0.000000  0.000000
# 2    Coming Soon in Manado City "All In One Aesthet...      0.377778  0.144444
# 3    Official Data for Hospitals in Manado City, No...      0.400000  0.100000
# 4    Official Data of Puskesmas in Manado City, Nor...      0.000000  0.000000
# ..                                                 ...           ...       ...
# 107  Manado City Won First Place in Universal Healt...      0.444444  0.383333
# 108  I'm at Prof. DR. Dr. Kandou Malalayang (Manado...      0.000000  0.000000
# 109  Thursday (03/10/2019) in Sam Ratulangi Hall, 4...      0.500000  0.050000
# 110  Residents Enthusiastically Welcome Free Health...      0.850000  0.600000
# 111  HBD city of manado ,,, long life with healthy ...      0.450000  0.225000
#
# [112 rows x 5 columns]

# %%
#wordcloud
allwords = ' '.join([twts for twts in df['text']])
wordCloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords)

plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
def getAnalysis(score):
    if score < 0 :
        return 'Negative'
    elif score == 0 :
        return 'Neutral'
    else :
        return 'Positive'

df['Sentiment'] = df['Polarity'].apply(getAnalysis)

df
# Out:
#                          created_at  \
# 0    Tue Jul 14 06:01:38 +0000 2020
# 1    Thu Feb 07 14:24:19 +0000 2019
# 2    Fri Aug 16 14:51:25 +0000 2013
# 3    Fri Feb 03 15:50:38 +0000 2017
# 4    Fri Jan 27 15:23:38 +0000 2017
# ..                              ...
# 107  Fri May 17 08:11:47 +0000 2013
# 108  Wed Aug 07 01:33:05 +0000 2013
# 109  Sat Oct 05 23:34:13 +0000 2019
# 110  Tue Feb 12 16:22:36 +0000 2019
# 111  Tue Jul 14 07:10:06 +0000 2015
#
#                                                   text  \
# 0    Kota Manado yang ku cintai Kita nyanda mo lupa...
# 1    DBD Makan Korban, Perindo Giatkan Fogging di K...
# 2    Segera Hadir di Kota Manado "Kursus Estetika A...
# 3    Data Resmi Rumah Sakit di Kota Manado Provinsi...
# 4    Data Resmi Puskesmas di Kota Manado Provinsi S...
# ..                                                 ...
# 107  Kota Manado Juara I Kinerja Program Jaminan Ke...
# 108  I'm at RSUD Prof. DR. Dr. Kandou Malalayang (K...
# 109  Kamis (03/10/2019) di Aula Sam Ratulangi Lanta...
# 110  Warga Sambut Antusias Periksa Kesehatan Gratis...
# 111  HBD kota manado,,,panjang umur deng sehat seha...
#
#                                               tweet_en  Subjectivity  \
# 0    The city of Manado, which I love We love to fo...      0.575000
# 1    DHF Eats Victims, Perindo Activates Fogging in...      0.000000
# 2    Coming Soon in Manado City "All In One Aesthet...      0.377778
# 3    Official Data for Hospitals in Manado City, No...      0.400000
# 4    Official Data of Puskesmas in Manado City, Nor...      0.000000
# ..                                                 ...           ...
# 107  Manado City Won First Place in Universal Healt...      0.444444
# 108  I'm at Prof. DR. Dr. Kandou Malalayang (Manado...      0.000000
# 109  Thursday (03/10/2019) in Sam Ratulangi Hall, 4...      0.500000
# 110  Residents Enthusiastically Welcome Free Health...      0.850000
# 111  HBD city of manado ,,, long life with healthy ...      0.450000
#
#      Polarity Sentiment
# 0    0.475000  Positive
# 1    0.000000   Neutral
# 2    0.144444  Positive
# 3    0.100000  Positive
# 4    0.000000   Neutral
# ..        ...       ...
# 107  0.383333  Positive
# 108  0.000000   Neutral
# 109  0.050000  Positive
# 110  0.600000  Positive
# 111  0.225000  Positive
#
# [112 rows x 6 columns]

# %%
#plot the polarity and subjectivity
plt.figure(figsize =(8,6))
for i in range (0, df.shape[0]):
    plt.scatter(df['Polarity'][i], df['Subjectivity'][i], color = 'Blue')

plt.title("Sentiment Analysis Kabputane Luwu")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.show()

# %%
#Plot the sentiment
df['Sentiment'].value_counts()

plt.title("Sentiment Analysis Kabupaten Luwu")
plt.xlabel("Sentiment")
plt.ylabel("Counts")
df['Sentiment'].value_counts().plot(kind = "bar")
plt.show()

# %%
df_final = df[['created_at', 'text', 'Subjectivity', 'Polarity', 'Sentiment']]
df_final
# Out:
#                          created_at  \
# 0    Tue Jul 14 06:01:38 +0000 2020
# 1    Thu Feb 07 14:24:19 +0000 2019
# 2    Fri Aug 16 14:51:25 +0000 2013
# 3    Fri Feb 03 15:50:38 +0000 2017
# 4    Fri Jan 27 15:23:38 +0000 2017
# ..                              ...
# 107  Fri May 17 08:11:47 +0000 2013
# 108  Wed Aug 07 01:33:05 +0000 2013
# 109  Sat Oct 05 23:34:13 +0000 2019
# 110  Tue Feb 12 16:22:36 +0000 2019
# 111  Tue Jul 14 07:10:06 +0000 2015
#
#                                                   text  Subjectivity  \
# 0    Kota Manado yang ku cintai Kita nyanda mo lupa...      0.575000
# 1    DBD Makan Korban, Perindo Giatkan Fogging di K...      0.000000
# 2    Segera Hadir di Kota Manado "Kursus Estetika A...      0.377778
# 3    Data Resmi Rumah Sakit di Kota Manado Provinsi...      0.400000
# 4    Data Resmi Puskesmas di Kota Manado Provinsi S...      0.000000
# ..                                                 ...           ...
# 107  Kota Manado Juara I Kinerja Program Jaminan Ke...      0.444444
# 108  I'm at RSUD Prof. DR. Dr. Kandou Malalayang (K...      0.000000
# 109  Kamis (03/10/2019) di Aula Sam Ratulangi Lanta...      0.500000
# 110  Warga Sambut Antusias Periksa Kesehatan Gratis...      0.850000
# 111  HBD kota manado,,,panjang umur deng sehat seha...      0.450000
#
#      Polarity Sentiment
# 0    0.475000  Positive
# 1    0.000000   Neutral
# 2    0.144444  Positive
# 3    0.100000  Positive
# 4    0.000000   Neutral
# ..        ...       ...
# 107  0.383333  Positive
# 108  0.000000   Neutral
# 109  0.050000  Positive
# 110  0.600000  Positive
# 111  0.225000  Positive
#
# [112 rows x 5 columns]
