# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("bekasi.csv")
df.head()
# Out:
#                        created_at  ...                                           tweet_en
# 0  Thu Jul 09 10:40:34 +0000 2020  ...  Plt. Telaga Murni Puskesmas Gandatua Ariston S...
# 1  Tue May 28 03:12:47 +0000 2019  ...  Thalassemia Room and Blood Bank Bekasi Distric...
# 2  Fri Feb 05 11:30:47 +0000 2016  ...  Since the beginning of 2016, 7 people have die...
# 3  Wed Jun 10 03:15:05 +0000 2020  ...  Revealing Pregnancy Rate in Bekasi Regency dur...
# 4  Wed Feb 18 07:44:38 +0000 2015  ...  Latest: BREAKING NEWS: Former Managing Directo...
#
# [5 rows x 3 columns]

# %%
def cleanTxt(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text)
    text = re.sub(r'#', '', text)
    text = re.sub(r'RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/\S+', '', text)
    
    return text

df['tweet_en'] = df['tweet_en'].apply(cleanTxt)
df['text'] = df['text'].apply(cleanTxt)
df
# Out:
#                          created_at  ...                                           tweet_en
# 0    Thu Jul 09 10:40:34 +0000 2020  ...  Plt. Telaga Murni Puskesmas Gandatua Ariston S...
# 1    Tue May 28 03:12:47 +0000 2019  ...  Thalassemia Room and Blood Bank Bekasi Distric...
# 2    Fri Feb 05 11:30:47 +0000 2016  ...  Since the beginning of 2016, 7 people have die...
# 3    Wed Jun 10 03:15:05 +0000 2020  ...  Revealing Pregnancy Rate in Bekasi Regency dur...
# 4    Wed Feb 18 07:44:38 +0000 2015  ...  Latest: BREAKING NEWS: Former Managing Directo...
# ..                              ...  ...                                                ...
# 528  Fri Feb 13 00:26:19 +0000 2015  ...  InfoBUC Bekasi District's DHF cases have decre...
# 529  Thu Oct 30 16:07:57 +0000 2014  ...  How to go to Bekasi District Hospital using BP...
# 530  Tue May 07 15:26:14 +0000 2019  ...  The Chairperson of the Bekasi Regency KPU Is T...
# 531  Thu Jul 26 15:00:48 +0000 2018  ...  Out of 39 Puskesmas in Bekasi District, 3 Pusk...
# 532  Sat Mar 14 11:38:04 +0000 2020  ...  A Corona Virus Suspect Nurse Dies in Bekasi Re...
#
# [533 rows x 3 columns]

# %%
#mendapatkan subjectivity dan polarity
def getSubjectivity(text):
    c = str(text)
    return TextBlob(c).sentiment.subjectivity

def getPolarity(text):
    c = str(text)
    return TextBlob(c).sentiment.polarity

df['Subjectivity'] = df['tweet_en'].apply(getSubjectivity)
df['Polarity'] = df['tweet_en'].apply(getPolarity)

# %%
df
# Out:
#                          created_at  ... Polarity
# 0    Thu Jul 09 10:40:34 +0000 2020  ...    0.000
# 1    Tue May 28 03:12:47 +0000 2019  ...    0.000
# 2    Fri Feb 05 11:30:47 +0000 2016  ...   -0.125
# 3    Wed Jun 10 03:15:05 +0000 2020  ...    0.000
# 4    Wed Feb 18 07:44:38 +0000 2015  ...    0.250
# ..                              ...  ...      ...
# 528  Fri Feb 13 00:26:19 +0000 2015  ...   -0.400
# 529  Thu Oct 30 16:07:57 +0000 2014  ...    0.000
# 530  Tue May 07 15:26:14 +0000 2019  ...    0.000
# 531  Thu Jul 26 15:00:48 +0000 2018  ...    0.000
# 532  Sat Mar 14 11:38:04 +0000 2020  ...    0.000
#
# [533 rows x 5 columns]

# %%
#wordcloud
allwords = ' '.join([twts for twts in df['tweet_en']])
wordCloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords)

plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
#mendapatkan nilai sentimen
def getAnalysis(score):
    if score < 0 :
        return 'Negative'
    elif score == 0 :
        return 'Neutral'
    else :
        return 'Positive'

df['Sentiment'] = df['Polarity'].apply(getAnalysis)

df

# %%
#plot the polarity and subjectivity
plt.figure(figsize =(8,6))
for i in range (0, df.shape[0]):
    plt.scatter(df['Polarity'][i], df['Subjectivity'][i], color = 'Blue')

plt.title("Sentiment Analysis Bekasi")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.show()

# %%
#Plot the sentiment
df['Sentiment'].value_counts()

plt.title("Sentiment Analysis Bekasi")
plt.xlabel("Sentiment")
plt.ylabel("Counts")
df['Sentiment'].value_counts().plot(kind = "bar")
plt.show()

# %%
df_final = df[['created_at', 'text', 'Subjectivity', 'Polarity', 'Sentiment']]
df_final
# Out:
#                          created_at  ... Sentiment
# 0    Thu Jul 09 10:40:34 +0000 2020  ...   Neutral
# 1    Tue May 28 03:12:47 +0000 2019  ...   Neutral
# 2    Fri Feb 05 11:30:47 +0000 2016  ...  Negative
# 3    Wed Jun 10 03:15:05 +0000 2020  ...   Neutral
# 4    Wed Feb 18 07:44:38 +0000 2015  ...  Positive
# ..                              ...  ...       ...
# 528  Fri Feb 13 00:26:19 +0000 2015  ...  Negative
# 529  Thu Oct 30 16:07:57 +0000 2014  ...   Neutral
# 530  Tue May 07 15:26:14 +0000 2019  ...   Neutral
# 531  Thu Jul 26 15:00:48 +0000 2018  ...   Neutral
# 532  Sat Mar 14 11:38:04 +0000 2020  ...   Neutral
#
# [533 rows x 5 columns]

# %%
df_final.to_csv("sentiment_bekasi.csv")
