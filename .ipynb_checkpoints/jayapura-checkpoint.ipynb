# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("train_Kota Jayapura_Public Health .csv")
del df['full_text']

# %%
df.head()
# Out:
#    Unnamed: 0                      created_at  \
# 0           0  Mon Jul 27 00:28:11 +0000 2015
# 1           1  Sun Sep 09 04:48:19 +0000 2018
# 2           2  Wed Sep 24 14:00:51 +0000 2014
# 3           3  Wed May 10 03:54:43 +0000 2017
# 4           4  Thu Nov 01 19:06:55 +0000 2018
#
#                                                 text
# 0  #indonesia @arbib Sejumlah warga di Kelurahan ...
# 1  I'm at PMI RSUD Dok II | Unit Transfusi Darah ...
# 2  Dinkes Kota Jayapura Tuntas Bagi KelambuÂ Mala...
# 3  Penyerahan Kartu Indonesia Sehat oleh Presiden...
# 4  RSUD Dok II @Kota_Jayapura https://t.co/knseYm...

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity

df['Subjectivity'] = df['text'].apply(getSubjectivity)
df['Polarity'] = df['text'].apply(getPolarity)

# %%
df
# Out:
#      Unnamed: 0                      created_at  \
# 0             0  Mon Jul 27 00:28:11 +0000 2015
# 1             1  Sun Sep 09 04:48:19 +0000 2018
# 2             2  Wed Sep 24 14:00:51 +0000 2014
# 3             3  Wed May 10 03:54:43 +0000 2017
# 4             4  Thu Nov 01 19:06:55 +0000 2018
# ..          ...                             ...
# 125         125  Mon Feb 19 14:47:09 +0000 2018
# 126         126  Tue Jun 09 17:07:18 +0000 2020
# 127         127  Fri Nov 13 11:22:46 +0000 2020
# 128         128  Thu Oct 10 04:33:52 +0000 2019
# 129         129  Mon Feb 04 08:22:44 +0000 2019
#
#                                                   text  Subjectivity  Polarity
# 0    #indonesia @arbib Sejumlah warga di Kelurahan ...          0.00      0.00
# 1    I'm at PMI RSUD Dok II | Unit Transfusi Darah ...          0.00      0.00
# 2    Dinkes Kota Jayapura Tuntas Bagi KelambuÂ Mala...          0.00      0.00
# 3    Penyerahan Kartu Indonesia Sehat oleh Presiden...          0.00      0.00
# 4    RSUD Dok II @Kota_Jayapura https://t.co/knseYm...          0.00      0.00
# ..                                                 ...           ...       ...
# 125  Ratusan perusahaan di Kota Jayapura daftarkan ...          0.00      0.00
# 126  Tujuh Rumah Sakit Rujukan Covid-19 di Kota Jay...          0.55      0.35
# 127  Kapolresta Dampingi Walikota Resmikan Rumah Sa...          0.00      0.00
# 128  @Destro76293786 @dilanarya @satriosoediro @ima...          0.00      0.00
# 129  Berantas malaria, Satgas Pamtas RI â PNG tek...          0.00      0.00
#
# [130 rows x 5 columns]

# %%
#wordcloud
allwords = ' '.join([twts for twts in df['text']])
wordCloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords)

plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
def getAnalysis(score):
    if score < 0 :
        return 'Negative'
    elif score == 0 :
        return 'Neutral'
    else :
        return 'Positive'

df['Analysis'] = df['Polarity'].apply(getAnalysis)

df
# Out:
#      Unnamed: 0                      created_at  \
# 0             0  Mon Jul 27 00:28:11 +0000 2015
# 1             1  Sun Sep 09 04:48:19 +0000 2018
# 2             2  Wed Sep 24 14:00:51 +0000 2014
# 3             3  Wed May 10 03:54:43 +0000 2017
# 4             4  Thu Nov 01 19:06:55 +0000 2018
# ..          ...                             ...
# 125         125  Mon Feb 19 14:47:09 +0000 2018
# 126         126  Tue Jun 09 17:07:18 +0000 2020
# 127         127  Fri Nov 13 11:22:46 +0000 2020
# 128         128  Thu Oct 10 04:33:52 +0000 2019
# 129         129  Mon Feb 04 08:22:44 +0000 2019
#
#                                                   text  Subjectivity  \
# 0    #indonesia @arbib Sejumlah warga di Kelurahan ...          0.00
# 1    I'm at PMI RSUD Dok II | Unit Transfusi Darah ...          0.00
# 2    Dinkes Kota Jayapura Tuntas Bagi KelambuÂ Mala...          0.00
# 3    Penyerahan Kartu Indonesia Sehat oleh Presiden...          0.00
# 4    RSUD Dok II @Kota_Jayapura https://t.co/knseYm...          0.00
# ..                                                 ...           ...
# 125  Ratusan perusahaan di Kota Jayapura daftarkan ...          0.00
# 126  Tujuh Rumah Sakit Rujukan Covid-19 di Kota Jay...          0.55
# 127  Kapolresta Dampingi Walikota Resmikan Rumah Sa...          0.00
# 128  @Destro76293786 @dilanarya @satriosoediro @ima...          0.00
# 129  Berantas malaria, Satgas Pamtas RI â PNG tek...          0.00
#
#      Polarity  Analysis
# 0        0.00   Neutral
# 1        0.00   Neutral
# 2        0.00   Neutral
# 3        0.00   Neutral
# 4        0.00   Neutral
# ..        ...       ...
# 125      0.00   Neutral
# 126      0.35  Positive
# 127      0.00   Neutral
# 128      0.00   Neutral
# 129      0.00   Neutral
#
# [130 rows x 6 columns]
