# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("manado.csv")
df.head()
# Out:
#                        created_at  ...                                           tweet_en
# 0  Tue Jul 14 06:01:38 +0000 2020  ...  The city of Manado, which I love We love to fo...
# 1  Thu Feb 07 14:24:19 +0000 2019  ...  DHF Eats Victims, Perindo Activates Fogging in...
# 2  Fri Aug 16 14:51:25 +0000 2013  ...  Coming Soon in Manado City "All In One Aesthet...
# 3  Fri Feb 03 15:50:38 +0000 2017  ...  Official Data for Hospitals in Manado City, No...
# 4  Fri Jan 27 15:23:38 +0000 2017  ...  Official Data of Puskesmas in Manado City, Nor...
#
# [5 rows x 3 columns]

# %%
def cleanTxt(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text)
    text = re.sub(r'#', '', text)
    text = re.sub(r'RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/\S+', '', text)
    
    return text

df['tweet_en'] = df['tweet_en'].apply(cleanTxt)
df['text'] = df['text'].apply(cleanTxt)
df
# Out:
#                          created_at  ...                                           tweet_en
# 0    Tue Jul 14 06:01:38 +0000 2020  ...  The city of Manado, which I love We love to fo...
# 1    Thu Feb 07 14:24:19 +0000 2019  ...  DHF Eats Victims, Perindo Activates Fogging in...
# 2    Fri Aug 16 14:51:25 +0000 2013  ...  Coming Soon in Manado City "All In One Aesthet...
# 3    Fri Feb 03 15:50:38 +0000 2017  ...  Official Data for Hospitals in Manado City, No...
# 4    Fri Jan 27 15:23:38 +0000 2017  ...  Official Data of Puskesmas in Manado City, Nor...
# ..                              ...  ...                                                ...
# 107  Fri May 17 08:11:47 +0000 2013  ...  Manado City Won First Place in Universal Healt...
# 108  Wed Aug 07 01:33:05 +0000 2013  ...  I'm at Prof. DR. Dr. Kandou Malalayang (Manado...
# 109  Sat Oct 05 23:34:13 +0000 2019  ...  Thursday (03/10/2019) in Sam Ratulangi Hall, 4...
# 110  Tue Feb 12 16:22:36 +0000 2019  ...  Residents Enthusiastically Welcome Free Health...
# 111  Tue Jul 14 07:10:06 +0000 2015  ...  HBD city of manado ,,, long life with healthy ...
#
# [112 rows x 3 columns]

# %%
#mendapatkan subjectivity dan polarity
def getSubjectivity(text):
    c = str(text)
    return TextBlob(c).sentiment.subjectivity

def getPolarity(text):
    c = str(text)
    return TextBlob(c).sentiment.polarity

df['Subjectivity'] = df['tweet_en'].apply(getSubjectivity)
df['Polarity'] = df['tweet_en'].apply(getPolarity)

# %%
df
# Out:
#                          created_at  ...  Polarity
# 0    Tue Jul 14 06:01:38 +0000 2020  ...  0.475000
# 1    Thu Feb 07 14:24:19 +0000 2019  ...  0.000000
# 2    Fri Aug 16 14:51:25 +0000 2013  ...  0.144444
# 3    Fri Feb 03 15:50:38 +0000 2017  ...  0.100000
# 4    Fri Jan 27 15:23:38 +0000 2017  ...  0.000000
# ..                              ...  ...       ...
# 107  Fri May 17 08:11:47 +0000 2013  ...  0.383333
# 108  Wed Aug 07 01:33:05 +0000 2013  ...  0.000000
# 109  Sat Oct 05 23:34:13 +0000 2019  ...  0.050000
# 110  Tue Feb 12 16:22:36 +0000 2019  ...  0.600000
# 111  Tue Jul 14 07:10:06 +0000 2015  ...  0.225000
#
# [112 rows x 5 columns]

# %%
#wordcloud
allwords = ' '.join([twts for twts in df['tweet_en']])
wordCloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords)

plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
#mendapatkan nilai sentimen
def getAnalysis(score):
    if score < 0 :
        return 'Negative'
    elif score == 0 :
        return 'Neutral'
    else :
        return 'Positive'

df['Sentiment'] = df['Polarity'].apply(getAnalysis)

df
# Out:
#                          created_at  ... Sentiment
# 0    Tue Jul 14 06:01:38 +0000 2020  ...  Positive
# 1    Thu Feb 07 14:24:19 +0000 2019  ...   Neutral
# 2    Fri Aug 16 14:51:25 +0000 2013  ...  Positive
# 3    Fri Feb 03 15:50:38 +0000 2017  ...  Positive
# 4    Fri Jan 27 15:23:38 +0000 2017  ...   Neutral
# ..                              ...  ...       ...
# 107  Fri May 17 08:11:47 +0000 2013  ...  Positive
# 108  Wed Aug 07 01:33:05 +0000 2013  ...   Neutral
# 109  Sat Oct 05 23:34:13 +0000 2019  ...  Positive
# 110  Tue Feb 12 16:22:36 +0000 2019  ...  Positive
# 111  Tue Jul 14 07:10:06 +0000 2015  ...  Positive
#
# [112 rows x 6 columns]

# %%
#plot the polarity and subjectivity
plt.figure(figsize =(8,6))
for i in range (0, df.shape[0]):
    plt.scatter(df['Polarity'][i], df['Subjectivity'][i], color = 'Blue')

plt.title("Sentiment Analysis Manado")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.show()

# %%
#Plot the sentiment
df['Sentiment'].value_counts()

plt.title("Sentiment Analysis Manado")
plt.xlabel("Sentiment")
plt.ylabel("Counts")
df['Sentiment'].value_counts().plot(kind = "bar")
plt.show()

# %%
df_final = df[['created_at', 'text', 'Subjectivity', 'Polarity', 'Sentiment']]
df_final
# Out:
#                          created_at  ... Sentiment
# 0    Tue Jul 14 06:01:38 +0000 2020  ...  Positive
# 1    Thu Feb 07 14:24:19 +0000 2019  ...   Neutral
# 2    Fri Aug 16 14:51:25 +0000 2013  ...  Positive
# 3    Fri Feb 03 15:50:38 +0000 2017  ...  Positive
# 4    Fri Jan 27 15:23:38 +0000 2017  ...   Neutral
# ..                              ...  ...       ...
# 107  Fri May 17 08:11:47 +0000 2013  ...  Positive
# 108  Wed Aug 07 01:33:05 +0000 2013  ...   Neutral
# 109  Sat Oct 05 23:34:13 +0000 2019  ...  Positive
# 110  Tue Feb 12 16:22:36 +0000 2019  ...  Positive
# 111  Tue Jul 14 07:10:06 +0000 2015  ...  Positive
#
# [112 rows x 5 columns]

# %%
df_final.to_csv("sentiment_manado.csv")
