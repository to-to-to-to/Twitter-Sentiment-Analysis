# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("datasets train/palembang.csv")

# %%
df.head()
# Out:
#                        created_at  \
# 0  Fri Jan 27 14:55:22 +0000 2017
# 1  Mon Aug 11 07:57:11 +0000 2014
# 2  Mon Jun 15 08:30:28 +0000 2020
# 3  Mon Mar 07 09:47:35 +0000 2016
# 4  Fri Jun 21 12:27:10 +0000 2019
#
#                                                 text  \
# 0  Data Resmi Puskesmas di Kota Palembang Provins...
# 1  Dinkes imbau pedagang jual makanan sehat: Dina...
# 2  Warga di komplek Bumi Sako Damai Kota Palemban...
# 3  Status Terakhir di WA Dokter Cantik Asal Balik...
# 4  Assalamu'alaikum SanakDulur DPPKB, Hari Jumat ...
#
#                                             tweet_en
# 0  Official Data of Puskesmas in Palembang City, ...
# 1  Health Office urges merchants to sell healthy ...
# 2  Residents in the Bumi Sako Damai complex in Pa...
# 3  The last status in WA, a beautiful doctor from...
# 4  Assalamu'alaikum SanakDulur DPPKB, Friday (21/...

# %%
def getSubjectivity(text):
    c = str(text)
    return TextBlob(c).sentiment.subjectivity

def getPolarity(text):
    c = str(text)
    return TextBlob(c).sentiment.polarity

df['Subjectivity'] = df['tweet_en'].apply(getSubjectivity)
df['Polarity'] = df['tweet_en'].apply(getPolarity)

# %%
df
# Out:
#                          created_at  \
# 0    Fri Jan 27 14:55:22 +0000 2017
# 1    Mon Aug 11 07:57:11 +0000 2014
# 2    Mon Jun 15 08:30:28 +0000 2020
# 3    Mon Mar 07 09:47:35 +0000 2016
# 4    Fri Jun 21 12:27:10 +0000 2019
# ..                              ...
# 245  Mon Sep 07 09:00:04 +0000 2015
# 246  Mon Jul 11 09:09:00 +0000 2016
# 247  Fri Feb 06 16:12:56 +0000 2015
# 248  Thu Jan 18 06:03:25 +0000 2018
# 249  Mon Sep 23 13:00:01 +0000 2019
#
#                                                   text  \
# 0    Data Resmi Puskesmas di Kota Palembang Provins...
# 1    Dinkes imbau pedagang jual makanan sehat: Dina...
# 2    Warga di komplek Bumi Sako Damai Kota Palemban...
# 3    Status Terakhir di WA Dokter Cantik Asal Balik...
# 4    Assalamu'alaikum SanakDulur DPPKB, Hari Jumat ...
# ..                                                 ...
# 245  Kota Palembang Diusulkan Jadi Kota Sehat http:...
# 246  Rumah Sakit di Kota Palembang Terima Ancaman T...
# 247  Palembang - Palembang belum status KLB DBD: Pe...
# 248  #PindangPatin Pemerintah Kota Palembang Sumate...
# 249  Peserta JKN-KIS Kota Palembang Tembus 95,28 Pe...
#
#                                               tweet_en  Subjectivity  Polarity
# 0    Official Data of Puskesmas in Palembang City, ...      0.000000  0.000000
# 1    Health Office urges merchants to sell healthy ...      0.500000  0.500000
# 2    Residents in the Bumi Sako Damai complex in Pa...      0.400000 -0.300000
# 3    The last status in WA, a beautiful doctor from...      0.372222  0.216667
# 4    Assalamu'alaikum SanakDulur DPPKB, Friday (21/...      0.000000  0.000000
# ..                                                 ...           ...       ...
# 245  Palembang City Is Proposed To Be A Healthy Cit...      0.500000  0.500000
# 246  Hospital in Palembang City Receives Bomb Terro...      0.000000  0.000000
# 247  Palembang - Palembang is not yet a DHF outbrea...      0.100000  0.000000
# 248  #PindangPatin Palembang City Government of Sou...      0.000000  0.000000
# 249  JKN-KIS Participants in Palembang City Translu...      0.000000  0.000000
#
# [250 rows x 5 columns]

# %%
#wordcloud
allwords = ' '.join([twts for twts in df['text']])
wordCloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords)

plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
def getAnalysis(score):
    if score < 0 :
        return 'Negative'
    elif score == 0 :
        return 'Neutral'
    else :
        return 'Positive'

df['Sentiment'] = df['Polarity'].apply(getAnalysis)

df
# Out:
#                          created_at  \
# 0    Fri Jan 27 14:55:22 +0000 2017
# 1    Mon Aug 11 07:57:11 +0000 2014
# 2    Mon Jun 15 08:30:28 +0000 2020
# 3    Mon Mar 07 09:47:35 +0000 2016
# 4    Fri Jun 21 12:27:10 +0000 2019
# ..                              ...
# 245  Mon Sep 07 09:00:04 +0000 2015
# 246  Mon Jul 11 09:09:00 +0000 2016
# 247  Fri Feb 06 16:12:56 +0000 2015
# 248  Thu Jan 18 06:03:25 +0000 2018
# 249  Mon Sep 23 13:00:01 +0000 2019
#
#                                                   text  \
# 0    Data Resmi Puskesmas di Kota Palembang Provins...
# 1    Dinkes imbau pedagang jual makanan sehat: Dina...
# 2    Warga di komplek Bumi Sako Damai Kota Palemban...
# 3    Status Terakhir di WA Dokter Cantik Asal Balik...
# 4    Assalamu'alaikum SanakDulur DPPKB, Hari Jumat ...
# ..                                                 ...
# 245  Kota Palembang Diusulkan Jadi Kota Sehat http:...
# 246  Rumah Sakit di Kota Palembang Terima Ancaman T...
# 247  Palembang - Palembang belum status KLB DBD: Pe...
# 248  #PindangPatin Pemerintah Kota Palembang Sumate...
# 249  Peserta JKN-KIS Kota Palembang Tembus 95,28 Pe...
#
#                                               tweet_en  Subjectivity  \
# 0    Official Data of Puskesmas in Palembang City, ...      0.000000
# 1    Health Office urges merchants to sell healthy ...      0.500000
# 2    Residents in the Bumi Sako Damai complex in Pa...      0.400000
# 3    The last status in WA, a beautiful doctor from...      0.372222
# 4    Assalamu'alaikum SanakDulur DPPKB, Friday (21/...      0.000000
# ..                                                 ...           ...
# 245  Palembang City Is Proposed To Be A Healthy Cit...      0.500000
# 246  Hospital in Palembang City Receives Bomb Terro...      0.000000
# 247  Palembang - Palembang is not yet a DHF outbrea...      0.100000
# 248  #PindangPatin Palembang City Government of Sou...      0.000000
# 249  JKN-KIS Participants in Palembang City Translu...      0.000000
#
#      Polarity Sentiment
# 0    0.000000   Neutral
# 1    0.500000  Positive
# 2   -0.300000  Negative
# 3    0.216667  Positive
# 4    0.000000   Neutral
# ..        ...       ...
# 245  0.500000  Positive
# 246  0.000000   Neutral
# 247  0.000000   Neutral
# 248  0.000000   Neutral
# 249  0.000000   Neutral
#
# [250 rows x 6 columns]

# %%
#plot the polarity and subjectivity
plt.figure(figsize =(8,6))
for i in range (0, df.shape[0]):
    plt.scatter(df['Polarity'][i], df['Subjectivity'][i], color = 'Blue')

plt.title("Sentiment Analysis Kabputane Luwu")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.show()

# %%
#Plot the sentiment
df['Sentiment'].value_counts()

plt.title("Sentiment Analysis Kabupaten Luwu")
plt.xlabel("Sentiment")
plt.ylabel("Counts")
df['Sentiment'].value_counts().plot(kind = "bar")
plt.show()

# %%
df_final = df[['created_at', 'text', 'Subjectivity', 'Polarity', 'Sentiment']]
df_final
# Out:
#                          created_at  \
# 0    Fri Jan 27 14:55:22 +0000 2017
# 1    Mon Aug 11 07:57:11 +0000 2014
# 2    Mon Jun 15 08:30:28 +0000 2020
# 3    Mon Mar 07 09:47:35 +0000 2016
# 4    Fri Jun 21 12:27:10 +0000 2019
# ..                              ...
# 245  Mon Sep 07 09:00:04 +0000 2015
# 246  Mon Jul 11 09:09:00 +0000 2016
# 247  Fri Feb 06 16:12:56 +0000 2015
# 248  Thu Jan 18 06:03:25 +0000 2018
# 249  Mon Sep 23 13:00:01 +0000 2019
#
#                                                   text  Subjectivity  \
# 0    Data Resmi Puskesmas di Kota Palembang Provins...      0.000000
# 1    Dinkes imbau pedagang jual makanan sehat: Dina...      0.500000
# 2    Warga di komplek Bumi Sako Damai Kota Palemban...      0.400000
# 3    Status Terakhir di WA Dokter Cantik Asal Balik...      0.372222
# 4    Assalamu'alaikum SanakDulur DPPKB, Hari Jumat ...      0.000000
# ..                                                 ...           ...
# 245  Kota Palembang Diusulkan Jadi Kota Sehat http:...      0.500000
# 246  Rumah Sakit di Kota Palembang Terima Ancaman T...      0.000000
# 247  Palembang - Palembang belum status KLB DBD: Pe...      0.100000
# 248  #PindangPatin Pemerintah Kota Palembang Sumate...      0.000000
# 249  Peserta JKN-KIS Kota Palembang Tembus 95,28 Pe...      0.000000
#
#      Polarity Sentiment
# 0    0.000000   Neutral
# 1    0.500000  Positive
# 2   -0.300000  Negative
# 3    0.216667  Positive
# 4    0.000000   Neutral
# ..        ...       ...
# 245  0.500000  Positive
# 246  0.000000   Neutral
# 247  0.000000   Neutral
# 248  0.000000   Neutral
# 249  0.000000   Neutral
#
# [250 rows x 5 columns]
