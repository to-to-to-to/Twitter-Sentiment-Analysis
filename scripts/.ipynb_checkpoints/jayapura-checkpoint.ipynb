# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("datasets train/jayapura1.csv")

# %%
df.head()
# Out:
#                        created_at  \
# 0  Mon Jul 27 00:28:11 +0000 2015
# 1  Sun Sep 09 04:48:19 +0000 2018
# 2  Wed Sep 24 14:00:51 +0000 2014
# 3  Wed May 10 03:54:43 +0000 2017
# 4  Thu Nov 01 19:06:55 +0000 2018
#
#                                                 text  \
# 0  #indonesia @arbib Sejumlah warga di Kelurahan ...
# 1  I'm at PMI RSUD Dok II | Unit Transfusi Darah ...
# 2  Dinkes Kota Jayapura Tuntas Bagi KelambuÃ‚Â Ma...
# 3  Penyerahan Kartu Indonesia Sehat oleh Presiden...
# 4  RSUD Dok II @Kota_Jayapura https://t.co/knseYm...
#
#                                             tweet_en
# 0  #indonesia @arbib A number of residents in Abe...
# 1  I'm at PMI RSUD Dok II | Jayapura City Blood T...
# 2  Jayapura City Health Office Completely Distrib...
# 3  Presentation of the Healthy Indonesia Card by ...
# 4  RSUD Dok II @Kota_Jayapura https://t.co/knseYm...

# %%
'''

def textTranslate(text):
    strText = str( text.strip() )
    traslatedblob = TextBlob( strText ).translate(to='en')
    strTranslated = str(traslatedblob) 
    return strTranslated

df['tweet_en'] = df['text'].str.encode('ascii', 'ignore').apply(textTranslate)
''''''
# Out:
#   File "<ipython-input-4-f04c00cdec92>", line 10
#     ''''''
#
# ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
df
# Out:
#                          created_at  \
# 0    Mon Jul 27 00:28:11 +0000 2015
# 1    Sun Sep 09 04:48:19 +0000 2018
# 2    Wed Sep 24 14:00:51 +0000 2014
# 3    Wed May 10 03:54:43 +0000 2017
# 4    Thu Nov 01 19:06:55 +0000 2018
# ..                              ...
# 118  Mon Feb 19 14:47:09 +0000 2018
# 119  Tue Jun 09 17:07:18 +0000 2020
# 120  Fri Nov 13 11:22:46 +0000 2020
# 121  Thu Oct 10 04:33:52 +0000 2019
# 122  Mon Feb 04 08:22:44 +0000 2019
#
#                                                   text  \
# 0    #indonesia @arbib Sejumlah warga di Kelurahan ...
# 1    I'm at PMI RSUD Dok II | Unit Transfusi Darah ...
# 2    Dinkes Kota Jayapura Tuntas Bagi KelambuÃ‚Â Ma...
# 3    Penyerahan Kartu Indonesia Sehat oleh Presiden...
# 4    RSUD Dok II @Kota_Jayapura https://t.co/knseYm...
# ..                                                 ...
# 118  Ratusan perusahaan di Kota Jayapura daftarkan ...
# 119  Tujuh Rumah Sakit Rujukan Covid-19 di Kota Jay...
# 120  Kapolresta Dampingi Walikota Resmikan Rumah Sa...
# 121  @Destro76293786 @dilanarya @satriosoediro @ima...
# 122  Berantas malaria, Satgas Pamtas RI Ã¢Â€Â“ PNG ...
#
#                                               tweet_en
# 0    #indonesia @arbib A number of residents in Abe...
# 1    I'm at PMI RSUD Dok II | Jayapura City Blood T...
# 2    Jayapura City Health Office Completely Distrib...
# 3    Presentation of the Healthy Indonesia Card by ...
# 4    RSUD Dok II @Kota_Jayapura https://t.co/knseYm...
# ..                                                 ...
# 118  Hundreds of companies in Jayapura City registe...
# 119  Seven Covid-19 Referral Hospitals in Jayapura ...
# 120  Kapolresta Accompanying the Mayor Inaugurates ...
# 121  @ Destro76293786 @dilanarya @satriosoediro @im...
# 122  Eradicating malaria, the Indonesian Military S...
#
# [123 rows x 3 columns]

# %%
def getSubjectivity(text):
    c = str(text)
    return TextBlob(c).sentiment.subjectivity

def getPolarity(text):
    c = str(text)
    return TextBlob(c).sentiment.polarity

df['Subjectivity'] = df['tweet_en'].apply(getSubjectivity)
df['Polarity'] = df['tweet_en'].apply(getPolarity)

# %%
df
# Out:
#                          created_at  \
# 0    Mon Jul 27 00:28:11 +0000 2015
# 1    Sun Sep 09 04:48:19 +0000 2018
# 2    Wed Sep 24 14:00:51 +0000 2014
# 3    Wed May 10 03:54:43 +0000 2017
# 4    Thu Nov 01 19:06:55 +0000 2018
# ..                              ...
# 118  Mon Feb 19 14:47:09 +0000 2018
# 119  Tue Jun 09 17:07:18 +0000 2020
# 120  Fri Nov 13 11:22:46 +0000 2020
# 121  Thu Oct 10 04:33:52 +0000 2019
# 122  Mon Feb 04 08:22:44 +0000 2019
#
#                                                   text  \
# 0    #indonesia @arbib Sejumlah warga di Kelurahan ...
# 1    I'm at PMI RSUD Dok II | Unit Transfusi Darah ...
# 2    Dinkes Kota Jayapura Tuntas Bagi KelambuÃ‚Â Ma...
# 3    Penyerahan Kartu Indonesia Sehat oleh Presiden...
# 4    RSUD Dok II @Kota_Jayapura https://t.co/knseYm...
# ..                                                 ...
# 118  Ratusan perusahaan di Kota Jayapura daftarkan ...
# 119  Tujuh Rumah Sakit Rujukan Covid-19 di Kota Jay...
# 120  Kapolresta Dampingi Walikota Resmikan Rumah Sa...
# 121  @Destro76293786 @dilanarya @satriosoediro @ima...
# 122  Berantas malaria, Satgas Pamtas RI Ã¢Â€Â“ PNG ...
#
#                                               tweet_en  Subjectivity  Polarity
# 0    #indonesia @arbib A number of residents in Abe...          0.00      0.00
# 1    I'm at PMI RSUD Dok II | Jayapura City Blood T...          0.00      0.00
# 2    Jayapura City Health Office Completely Distrib...          0.40      0.10
# 3    Presentation of the Healthy Indonesia Card by ...          0.50      0.50
# 4    RSUD Dok II @Kota_Jayapura https://t.co/knseYm...          0.00      0.00
# ..                                                 ...           ...       ...
# 118  Hundreds of companies in Jayapura City registe...          0.00      0.00
# 119  Seven Covid-19 Referral Hospitals in Jayapura ...          0.55      0.35
# 120  Kapolresta Accompanying the Mayor Inaugurates ...          0.00      0.00
# 121  @ Destro76293786 @dilanarya @satriosoediro @im...          0.00      0.00
# 122  Eradicating malaria, the Indonesian Military S...          0.10     -0.10
#
# [123 rows x 5 columns]

# %%
#wordcloud
allwords = ' '.join([twts for twts in df['text']])
wordCloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords)

plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
def getAnalysis(score):
    if score < 0 :
        return 'Negative'
    elif score == 0 :
        return 'Neutral'
    else :
        return 'Positive'

df['Sentiment'] = df['Polarity'].apply(getAnalysis)

df
# Out:
#                          created_at  \
# 0    Mon Jul 27 00:28:11 +0000 2015
# 1    Sun Sep 09 04:48:19 +0000 2018
# 2    Wed Sep 24 14:00:51 +0000 2014
# 3    Wed May 10 03:54:43 +0000 2017
# 4    Thu Nov 01 19:06:55 +0000 2018
# ..                              ...
# 118  Mon Feb 19 14:47:09 +0000 2018
# 119  Tue Jun 09 17:07:18 +0000 2020
# 120  Fri Nov 13 11:22:46 +0000 2020
# 121  Thu Oct 10 04:33:52 +0000 2019
# 122  Mon Feb 04 08:22:44 +0000 2019
#
#                                                   text  \
# 0    #indonesia @arbib Sejumlah warga di Kelurahan ...
# 1    I'm at PMI RSUD Dok II | Unit Transfusi Darah ...
# 2    Dinkes Kota Jayapura Tuntas Bagi KelambuÃ‚Â Ma...
# 3    Penyerahan Kartu Indonesia Sehat oleh Presiden...
# 4    RSUD Dok II @Kota_Jayapura https://t.co/knseYm...
# ..                                                 ...
# 118  Ratusan perusahaan di Kota Jayapura daftarkan ...
# 119  Tujuh Rumah Sakit Rujukan Covid-19 di Kota Jay...
# 120  Kapolresta Dampingi Walikota Resmikan Rumah Sa...
# 121  @Destro76293786 @dilanarya @satriosoediro @ima...
# 122  Berantas malaria, Satgas Pamtas RI Ã¢Â€Â“ PNG ...
#
#                                               tweet_en  Subjectivity  \
# 0    #indonesia @arbib A number of residents in Abe...          0.00
# 1    I'm at PMI RSUD Dok II | Jayapura City Blood T...          0.00
# 2    Jayapura City Health Office Completely Distrib...          0.40
# 3    Presentation of the Healthy Indonesia Card by ...          0.50
# 4    RSUD Dok II @Kota_Jayapura https://t.co/knseYm...          0.00
# ..                                                 ...           ...
# 118  Hundreds of companies in Jayapura City registe...          0.00
# 119  Seven Covid-19 Referral Hospitals in Jayapura ...          0.55
# 120  Kapolresta Accompanying the Mayor Inaugurates ...          0.00
# 121  @ Destro76293786 @dilanarya @satriosoediro @im...          0.00
# 122  Eradicating malaria, the Indonesian Military S...          0.10
#
#      Polarity Sentiment
# 0        0.00   Neutral
# 1        0.00   Neutral
# 2        0.10  Positive
# 3        0.50  Positive
# 4        0.00   Neutral
# ..        ...       ...
# 118      0.00   Neutral
# 119      0.35  Positive
# 120      0.00   Neutral
# 121      0.00   Neutral
# 122     -0.10  Negative
#
# [123 rows x 6 columns]

# %%
#plot the polarity and subjectivity
plt.figure(figsize =(8,6))
for i in range (0, df.shape[0]):
    plt.scatter(df['Polarity'][i], df['Subjectivity'][i], color = 'Blue')

plt.title("Sentiment Analysis Jayapura")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.show()

# %%
#Plot the sentiment
df['Sentiment'].value_counts()

plt.title("Sentiment Analysis Jayapura")
plt.xlabel("Sentiment")
plt.ylabel("Counts")
df['Sentiment'].value_counts().plot(kind = "bar")
plt.show()

# %%
df_final = df[['created_at', 'text', 'Subjectivity', 'Polarity', 'Sentiment']]

# %%
df_final
# Out:
#                          created_at  \
# 0    Mon Jul 27 00:28:11 +0000 2015
# 1    Sun Sep 09 04:48:19 +0000 2018
# 2    Wed Sep 24 14:00:51 +0000 2014
# 3    Wed May 10 03:54:43 +0000 2017
# 4    Thu Nov 01 19:06:55 +0000 2018
# ..                              ...
# 118  Mon Feb 19 14:47:09 +0000 2018
# 119  Tue Jun 09 17:07:18 +0000 2020
# 120  Fri Nov 13 11:22:46 +0000 2020
# 121  Thu Oct 10 04:33:52 +0000 2019
# 122  Mon Feb 04 08:22:44 +0000 2019
#
#                                                   text  Subjectivity  \
# 0    #indonesia @arbib Sejumlah warga di Kelurahan ...          0.00
# 1    I'm at PMI RSUD Dok II | Unit Transfusi Darah ...          0.00
# 2    Dinkes Kota Jayapura Tuntas Bagi KelambuÃ‚Â Ma...          0.40
# 3    Penyerahan Kartu Indonesia Sehat oleh Presiden...          0.50
# 4    RSUD Dok II @Kota_Jayapura https://t.co/knseYm...          0.00
# ..                                                 ...           ...
# 118  Ratusan perusahaan di Kota Jayapura daftarkan ...          0.00
# 119  Tujuh Rumah Sakit Rujukan Covid-19 di Kota Jay...          0.55
# 120  Kapolresta Dampingi Walikota Resmikan Rumah Sa...          0.00
# 121  @Destro76293786 @dilanarya @satriosoediro @ima...          0.00
# 122  Berantas malaria, Satgas Pamtas RI Ã¢Â€Â“ PNG ...          0.10
#
#      Polarity Sentiment
# 0        0.00   Neutral
# 1        0.00   Neutral
# 2        0.10  Positive
# 3        0.50  Positive
# 4        0.00   Neutral
# ..        ...       ...
# 118      0.00   Neutral
# 119      0.35  Positive
# 120      0.00   Neutral
# 121      0.00   Neutral
# 122     -0.10  Negative
#
# [123 rows x 5 columns]
