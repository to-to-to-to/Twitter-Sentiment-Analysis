# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, Activation, Dropout
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalMaxPooling1D
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("train_Kota Jayapura_Public Health .csv")
df.head()
# Out:
#    Unnamed: 0                      created_at  \
# 0           0  Mon Jul 27 00:28:11 +0000 2015
# 1           1  Sun Sep 09 04:48:19 +0000 2018
# 2           2  Wed Sep 24 14:00:51 +0000 2014
# 3           3  Wed May 10 03:54:43 +0000 2017
# 4           4  Thu Nov 01 19:06:55 +0000 2018
#
#                                                 text full_text
# 0  #indonesia @arbib Sejumlah warga di Kelurahan ...       NaN
# 1  I'm at PMI RSUD Dok II | Unit Transfusi Darah ...       NaN
# 2  Dinkes Kota Jayapura Tuntas Bagi KelambuÂ Mala...       NaN
# 3  Penyerahan Kartu Indonesia Sehat oleh Presiden...       NaN
# 4  RSUD Dok II @Kota_Jayapura https://t.co/knseYm...       NaN

# %%
text = df["text"].tolist()
print(len(text))
# Out:
# 130

# %%
token = Tokenizer()
token.fit_on_texts(text)

# %%
token.index_word
# Out:
# {1: 't',
#  2: 'co',
#  3: 'jayapura',
#  4: 'kota',
#  5: 'https',
#  6: 'di',
#  7: 'papua',
#  8: 'http',
#  9: 'dinkes',
#  10: 'puskesmas',
#  11: 'kesehatan',
#  12: 'rumah',
#  13: 'sakit',
#  14: 'sehat',
#  15: 'dinas',
#  16: 'dan',
#  17: 'warga',
#  18: 'abepura',
#  19: 'provinsi',
#  20: 'distrik',
#  21: 'rsud',
#  22: 'dari',
#  23: 'indonesia',
#  24: 'walikota',
#  25: 'ini',
#  26: 'pasien',
#  27: 'pelayanan',
#  28: 'obat',
#  29: 'selangkah',
#  30: 'kepala',
#  31: 'malaria',
#  32: 'bpjs',
#  33: 'buat',
#  34: 'dok',
#  35: 'hari',
#  36: 'majalah',
#  37: 'untuk',
#  38: 'dengan',
#  39: 'yang',
#  40: 'mulai',
#  41: 'resmi',
#  42: 'republik',
#  43: 'lengkap',
#  44: 'covid',
#  45: '19',
#  46: 'angka',
#  47: 'pemerintah',
#  48: 'dbd',
#  49: 'bisa',
#  50: 'sejumlah',
#  51: 'kelurahan',
#  52: 'ii',
#  53: 'kampung',
#  54: 'hiv',
#  55: 'aids',
#  56: 'pelaksanaan',
#  57: '2020',
#  58: 'data',
#  59: 'dokter',
#  60: 'terima',
#  61: 'dr',
#  62: 'mengatakan',
#  63: 'abe',
#  64: 'berita',
#  65: 'dana',
#  66: 'satu',
#  67: 'ikut',
#  68: 'ibu',
#  69: 'butuh',
#  70: 'via',
#  71: 'abepantai',
#  72: 'bagi',
#  73: 'ri',
#  74: 'muara',
#  75: 'tami',
#  76: 'kis',
#  77: 'penyebaran',
#  78: 'gandeng',
#  79: 'menyerahkan',
#  80: 'tahun',
#  81: 'valid',
#  82: 'dolarina',
#  83: 'kepada',
#  84: 'penis',
#  85: 'keluar',
#  86: 'cairan',
#  87: 'nanah',
#  88: 'ampuh',
#  89: 'apotik',
#  90: 'de',
#  91: 'bersama',
#  92: 'terapkan',
#  93: 'papuauntuksemua',
#  94: 'adalah',
#  95: 'perindo',
#  96: 'reliable',
#  97: 'â\x80\x93',
#  98: 'imunisasi',
#  99: 'kasus',
#  100: 'jemput',
#  101: 'nyamuk',
#  102: 'jayapâ\x80¦',
#  103: 'turunkan',
#  104: 'salah',
#  105: 'benhur',
#  106: 'mano',
#  107: 'akan',
#  108: 'pembangunan',
#  109: 'koko',
#  110: 'ke',
#  111: 'kaki',
#  112: 'tenaga',
#  113: 'masih',
#  114: 'tni',
#  115: 'yg',
#  116: 'rantangan',
#  117: 'dirmh',
#  118: 'or',
#  119: 'kantor',
#  120: 'sekitar',
#  121: 'n',
#  122: 'hub',
#  123: '085292518828',
#  124: 'murah',
#  125: 'halal',
#  126: 'melakukan',
#  127: 'kurang',
#  128: 'terus',
#  129: 'publik',
#  130: '12',
#  131: 'darah',
#  132: 'oleh',
#  133: 'pkr',
#  134: 'kantongi',
#  135: 'daerah',
#  136: 'usai',
#  137: 'dokumen',
#  138: 'perubahan',
#  139: 'anggaran',
#  140: 'menyampaikan',
#  141: '3',
#  142: 'novembeâ\x80¦',
#  143: 'merupakan',
#  144: 'kita',
#  145: 'dorong',
#  146: '13',
#  147: 'pelatihan',
#  148: 'empat',
#  149: 'harga',
#  150: 'breving',
#  151: 'kab',
#  152: 'keerom',
#  153: 'sr',
#  154: 'ssr',
#  155: 'meminta',
#  156: 'inginkan',
#  157: 'pemprov',
#  158: 'program',
#  159: 'gerbangmas',
#  160: 'hasrat',
#  161: 'positif',
#  162: 'jamkespa',
#  163: 'meningkat',
#  164: 'rp3',
#  165: 'miliar',
#  166: 'mengklaim',
#  167: 'setiap',
#  168: 'tahu',
#  169: 'berantas',
#  170: 'budaya',
#  171: 'hidup',
#  172: 'penyakit',
#  173: 'jual',
#  174: 'tekad',
#  175: 'tekan',
#  176: 'tbc',
#  177: 'dirawat',
#  178: 'twittizen',
#  179: 'shared',
#  180: 'ungkap',
#  181: 'temuan',
#  182: '6',
#  183: '765',
#  184: 'tcbqdoqutt',
#  185: 'vm59lnhnwa',
#  186: 'jiwa',
#  187: 'selamatkan',
#  188: 'serangan',
#  189: 'rescue',
#  190: 'mengasapi',
#  191: 'lebih',
#  192: '200',
#  193: 'jadi',
#  194: 'ketenagakerjaan',
#  195: 'upaya',
#  196: 'penderitaâ\xa0malaria',
#  197: 'acv1v3fmme',
#  198: '44seme6vfy',
#  199: 'gays',
#  200: 'mcs',
#  201: 'koya',
#  202: 'barat',
#  203: 'kegiatan',
#  204: 'bola',
#  205: 'kesehaâ\x80¦',
#  206: '52iz018eut',
#  207: 'kabid',
#  208: 'â\x80¦',
#  209: 'dua',
#  210: 'nih',
#  211: 'buka',
#  212: 'medis',
#  213: 'kesembuhan',
#  214: 'perawat',
#  215: 'tp',
#  216: 'paksa',
#  217: 'jua',
#  218: 'kupang',
#  219: 'mo1pnexdye',
#  220: '14',
#  221: 'tomi',
#  222: 'mm',
#  223: 'marthen',
#  224: 'indey',
#  225: 'aryoko',
#  226: 'kotasentani',
#  227: 'tujuh',
#  228: 'sudah',
#  229: 'bpjsâ\xa0ketenagakerjaan',
#  230: 'sangat',
#  231: '24',
#  232: 'bapak',
#  233: '2',
#  234: 'cegah',
#  235: '150',
#  236: 'mampu',
#  237: 'kampanyekan',
#  238: 'pentingnya',
#  239: 'mrp',
#  240: 'sobat',
#  241: 'siap',
#  242: 'orang',
#  243: 'kusta',
#  244: 'tidak',
#  245: 'ratusan',
#  246: 'perusahaan',
#  247: 'daftarkan',
#  248: 'pekerjanya',
#  249: '62',
#  250: 'pendamping',
#  251: 'pkh',
#  252: 'sosialisasi',
#  253: 'anak',
#  254: 'kotaâ\xa0jayapura',
#  255: 'arbib',
#  256: 'oqtqwctznf',
#  257: 'trend',
#  258: 'mrarbib',
#  259: "i'm",
#  260: 'at',
#  261: 'pmi',
#  262: 'unit',
#  263: 'transfusi',
#  264: 'in',
#  265: 'dydwhlzkxh',
#  266: 'tuntas',
#  267: 'kelambuâ\xa0malaria',
#  268: 'phbyhpizfu',
#  269: 'penyerahan',
#  270: 'kartu',
#  271: 'presiden',
#  272: 'jkn',
#  273: 'xswumjki0y',
#  274: 'knseymmpav',
#  275: '18q5w1w4qa',
#  276: 'meredam',
#  277: 'difteri',
#  278: 'disepakati',
#  279: 'bahwa',
#  280: 'dokterâ\x80¦',
#  281: 'waymwntibg',
#  282: 'ipk',
#  283: 'gelar',
#  284: 'bakti',
#  285: 'sosial',
#  286: 'moso',
#  287: 'fhbmkfl3uy',
#  288: 'ce6jjehhxc',
#  289: 'aghypljhkr',
#  290: 'yclszxsjcd',
#  291: 'kondisi',
#  292: 'pembantu',
#  293: 'skou',
#  294: 'cj9euihynd',
#  295: 'lewat',
#  296: 'youtube',
#  297: 'htxqzvgnuh',
#  298: 'namsan',
#  299: 'wani',
#  300: 'bahagia',
#  301: 'karena',
#  302: 'pemimpin',
#  303: 'yaitu',
#  304: 'aiâ\x80¦',
#  305: 'e3n8gpc0zg',
#  306: 'terakreditasi',
#  307: '1kbbhjcofw',
#  308: 'kadinkes',
#  309: 'tengah',
#  310: 'memberikan',
#  311: 'materi',
#  312: 'phbs',
#  313: 'peserta',
#  314: 'kecil',
#  315: 'dhlbdflv4d',
#  316: 'penghargaan',
#  317: 'sebanyak',
#  318: 'mene',
#  319: 'ctpseld4ih',
#  320: 'y0fptiafgr',
#  321: 'djqbsx9tjc',
#  322: 'menuju',
#  323: 'iso',
#  324: 'akreditasi',
#  325: 'v7m0ig6al4',
#  326: 'z6uind5aeu',
#  327: 'penderita',
#  328: 'terbanyak',
#  329: 'skouw',
#  330: '1hqn7bx0tr',
#  331: 'pertemuan',
#  332: 'kordinasi',
#  333: 'sumber',
#  334: 'kdp',
#  335: 'fxkamorncn',
#  336: 'venztime',
#  337: 'k',
#  338: 'wqzdhxd0hy',
#  339: 'sebagian',
#  340: 'pantai',
#  341: 'fous9mpvsc',
#  342: 'baru',
#  343: 'dau51hex1u',
#  344: '60',
#  345: 'asn',
#  346: 'separuhnya',
#  347: 'pegawai',
#  348: 'artikel',
#  349: 'asli',
#  350: 'dimuat',
#  351: 'mitra',
#  352: 'teras',
#  353: 'juâ\x80¦',
#  354: 'tqjwyit8t9',
#  355: 'mwjlg9w6fr',
#  356: '1fl5k0qggf',
#  357: 'meninggalkan',
#  358: 'kotamanado',
#  359: 'ntt',
#  360: 'poskupang',
#  361: 'qherbieblu',
#  362: 'created',
#  363: 'uvmrjwfqls',
#  364: 'pap',
#  365: 'xnbhuprcbk',
#  366: 'pin',
#  367: 'capai',
#  368: '76',
#  369: '9',
#  370: 'persen',
#  371: 'jubi',
#  372: 'pencapaian',
#  373: 'pekan',
#  374: 'nasio',
#  375: 'blmj194aqm',
#  376: 'reportase',
#  377: 'pertama',
#  378: 'teknik',
#  379: 'komunikasi',
#  380: 'k4u5ptqvtm',
#  381: 'penuh',
#  382: 'puluhan',
#  383: '93sxkjdurn',
#  384: '49xcgnn6hf',
#  385: 'pengelola',
#  386: 'menyediakan',
#  387: 'antar',
#  388: 'a3ddzeqbqo',
#  389: 'bhjyjndekb',
#  390: 'yoka',
#  391: 'dipilih',
#  392: 'sadar',
#  393: 'harian',
#  394: 'teratas',
#  395: 'diminta',
#  396: 'tingkatkan',
#  397: '90fon3yk4h',
#  398: 'inaig9sq8u',
#  399: '2mjg3vk0g4',
#  400: 'tommy',
#  401: 'memimpin',
#  402: 'rapat',
#  403: 'evaluasi',
#  404: 'direktur',
#  405: 'nkraquxbpi',
#  406: 's',
#  407: 'hx0vlcrpty',
#  408: 'bangun',
#  409: 'unitâ\xa0puskesmas',
#  410: 'u5oficxxzb',
#  411: '8kxrvlppji',
#  412: 'fitnews',
#  413: 'fokus',
#  414: 'menata',
#  415: 'lokasi',
#  416: 'perumahan',
#  417: 'holtekam',
#  418: 'dusunâ\x80¦',
#  419: 'nlwc5hkbyf',
#  420: 'dorfeldave',
#  421: 'î°ï\x91âªð½',
#  422: 'kangen',
#  423: 'liatin',
#  424: 'tampil',
#  425: 'lagi',
#  426: 'cepat',
#  427: 'sembuh',
#  428: 'biar',
#  429: 'maen',
#  430: 'ë\x87ê\x83æªë\x87',
#  431: '5dexwaymqc',
#  432: 'kelas',
#  433: 'hamil',
#  434: 'ja',
#  435: 'pvgp2jgrsv',
#  436: 'tim',
#  437: 'nusantara',
#  438: 'kementrian',
#  439: 'oetapcc4ol',
#  440: 'yulianchrisna',
#  441: 'hi',
#  442: 'yulian',
#  443: 'kamu',
#  444: 'aktivasi',
#  445: 'bank',
#  446: 'cabang',
#  447: 'btpn',
#  448: 'alamat',
#  449: 'jl',
#  450: 'raya',
#  451: 'kotarajaâ\x80¦',
#  452: 'peghuoo6n6',
#  453: 'tertinggi',
#  454: 'faktor',
#  455: 'tingkat',
#  456: 'kaâ\x80¦',
#  457: 'r6rgjxkvys',
#  458: 'ppni',
#  459: 'permudah',
#  460: 'sertifikasi',
#  461: 'fdqxb1zlt6',
#  462: 'info',
#  463: 'apotek',
#  464: 'affsyzg6wa',
#  465: 'selasa',
#  466: 'april',
#  467: 'bertempat',
#  468: 'kediaman',
#  469: 'apdâ\x80¦',
#  470: 'gegwgdlsta',
#  471: 'stok',
#  472: 'reagen',
#  473: 'habis',
#  474: 'waena',
#  475: 'jayapuraâ\xa0habis',
#  476: 'gx9n3rrtfr',
#  477: 'arujltjlgn',
#  478: 'menerjunkan',
#  479: 'setempat',
#  480: 'titik',
#  481: 'terkena',
#  482: 'banjir',
#  483: 'ws07mfzlt9',
#  484: 'satunya',
#  485: 'belum',
#  486: 'punya',
#  487: 'raqqejjd',
#  488: 'anggota',
#  489: 'intelijen',
#  490: 'kodim',
#  491: '1701',
#  492: 'serma',
#  493: 'tugino',
#  494: 'pang',
#  495: 'klik',
#  496: '4nanikz7vc',
#  497: 'selain',
#  498: 'bandung',
#  499: 'smart',
#  500: 'city',
#  501: 'infonawacita',
#  502: 'siaran',
#  503: 'pers',
#  504: 'blog',
#  505: 'tindaklanjuti',
#  506: 'penanggulangan',
#  507: 'bz52rqm50b',
#  508: 'omaz2djree',
#  509: 'daftar',
#  510: '5h5bxymltu',
#  511: 'ngerlhm5dr',
#  512: 'terdaftar',
#  513: '37y1d55iza',
#  514: 'xcfji4lzrs',
#  515: 'letkol',
#  516: 'chk',
#  517: 'abdul',
#  518: 'rahman',
#  519: 'diduga',
#  520: 'bunuh',
#  521: 'diri',
#  522: 'akibat',
#  523: 'seorang',
#  524: 'perwira',
#  525: 'mak',
#  526: 'q1ehn7ytmn',
#  527: 'papuaupdate',
#  528: 'hal',
#  529: 'membuat',
#  530: 'rendah',
#  531: 'para',
#  532: 'terlalu',
#  533: 'terpusâ\x80¦',
#  534: 'hthsxe6pgg',
#  535: 'arif',
#  536: 'dwi',
#  537: 'darmanto',
#  538: 'hingga',
#  539: 'saat',
#  540: 'gedung',
#  541: 'sakitâ\x80¦',
#  542: 'ifoojommbi',
#  543: 'bukti',
#  544: 'nyata',
#  545: 'jamin',
#  546: 'warganya',
#  547: 'penandatanganan',
#  548: 'perjanjian',
#  549: 'kesehataâ\x80¦',
#  550: '3gv32zszqm',
#  551: 'dalam',
#  552: 'rangka',
#  553: 'haritoiletsedunia2019',
#  554: 'ternyata',
#  555: 'sanitasiaman',
#  556: 'dijalankan',
#  557: 'loh',
#  558: 'gfuj87wmff',
#  559: 'bantu',
#  560: 'keracunan',
#  561: 'kerahkan',
#  562: 'd2ocq5wuji',
#  563: 'alc0sekwg7',
#  564: 'sahid',
#  565: 'hotel',
#  566: 'disulap',
#  567: 'menjadi',
#  568: 'jaâ\x80¦',
#  569: 'pbcp4fiyx6',
#  570: 'wajibkan',
#  571: 'jam',
#  572: '1sspbij5mc',
#  573: 'tvonenews',
#  574: 'benar',
#  575: 'almarhumah',
#  576: 'kami',
#  577: 'awalnya',
#  578: 'masuk',
#  579: 'riwayat',
#  580: 'gula',
#  581: 'namâ\x80¦',
#  582: 'o7z5xd9jol',
#  583: 'ribuan',
#  584: 'jalan',
#  585: 'bumn',
#  586: 'hadir',
#  587: 'negeri',
#  588: 'x9qzmz0oop',
#  589: 'bisnis',
#  590: 'kabarpapua',
#  591: 'wujudkan',
#  592: 'layakâ\xa0anak',
#  593: 'sdqzuyx3v6',
#  594: 'jualan',
#  595: 'fiforlif',
#  596: 'boyke',
#  597: 'online',
#  598: 'sv7slnn8ux',
#  599: 'mqgvlflhwz',
#  600: 'lmdo7daodi',
#  601: 'lakukanâ\xa0fogging',
#  602: 'ymfrblhchq',
#  603: 'jeokbbpkpa',
#  604: 'rjzlhl4e7g',
#  605: 'bingung',
#  606: 'implementasiâ\xa0kps',
#  607: 'iafwmugize',
#  608: 'humas',
#  609: 'polda',
#  610: 'aksi',
#  611: 'tersebut',
#  612: 'bertujuan',
#  613: 'mencari',
#  614: 'guna',
#  615: 'meringankan',
#  616: 'peâ\x80¦',
#  617: 'fkitepyjv8',
#  618: 'beritapapua',
#  619: 'pemkot',
#  620: 'miliki',
#  621: 'bernama',
#  622: 'ramela',
#  623: 'peresmian',
#  624: 'didukungâ\x80¦',
#  625: 'jnugvwvyne',
#  626: 'pbiâ\xa0tambahan',
#  627: 'f8qehaw46vâ\xa0â\x80¦https',
#  628: '21ggmlfbgmâ\x80¦',
#  629: '39vtxuqdkl',
#  630: 'h4xyqlr4a6â\xa0',
#  631: 'bkcpuiwki4',
#  632: 'yivbov1bbu',
#  633: 'bekali',
#  634: 'keterampilan',
#  635: 'cinta',
#  636: 'cari',
#  637: 'temukan',
#  638: 'obatâ\x80¦',
#  639: 'rldbrgqthc',
#  640: 'iyah',
#  641: 'diralat',
#  642: 'sa',
#  643: 'liat',
#  644: 'videonya',
#  645: 'semoga',
#  646: 'semua',
#  647: 'lekas',
#  648: 'spt',
#  649: 'sedia',
#  650: 'kala',
#  651: 'masyarakat',
#  652: 'senin',
#  653: '23',
#  654: 'november',
#  655: 'terbuka',
#  656: 'kembali',
#  657: 'umum',
#  658: 'non',
#  659: 'coâ\x80¦',
#  660: '9bt6tw3so5',
#  661: 'minta',
#  662: 'berikan',
#  663: 'aps',
#  664: 'majalahâ\xa0',
#  665: 'keseha',
#  666: 'tabjpqlhwu',
#  667: '140',
#  668: 'terinfeksi',
#  669: 'virus',
#  670: 'korona',
#  671: 'itu',
#  672: 'berasal',
#  673: 'sembilan',
#  674: 'tersebar',
#  675: 'scrikri89w',
#  676: 'vmamqttzr2',
#  677: 'ayb9tgrgeqâ\xa0',
#  678: 'publikâ\x80¦â\x80¦',
#  679: 'b8qptlraxu',
#  680: 'raja',
#  681: 'singa',
#  682: 'toko',
#  683: 'herbal',
#  684: 'nature',
#  685: 'scoopit',
#  686: 'rncol4j8ey',
#  687: 'q79azn5rtiâ\x80¦â\x80¦',
#  688: 'xy2530kfd1',
#  689: 'browhltwek',
#  690: 'campak',
#  691: 'isi',
#  692: 'hkn',
#  693: 'lomba',
#  694: 'danâ\xa0seminar',
#  695: '70rcr7yu3g',
#  696: 'melalui',
#  697: 'eunddjqjx0',
#  698: 'zjipf8blor',
#  699: '4',
#  700: 'kloofkamp',
#  701: 'utara',
#  702: 'dilarikan',
#  703: 'pasca',
#  704: 'kebakaran',
#  705: 'gajah',
#  706: 'hamadi',
#  707: 'gencarkan',
#  708: 'pemberian',
#  709: '0tokp1l7gbâ\xa0â\x80¦',
#  710: '1uv8qfpans',
#  711: 'qhikkwzhdn',
#  712: 'pbi',
#  713: 'tambahan',
#  714: 'olslfdautgâ\xa0',
#  715: 'peristiwa',
#  716: 'kabarpapuaâ\x80¦',
#  717: 'jj9kjx83hs',
#  718: 'jalin',
#  719: 'kerjasama',
#  720: 'aptsp',
#  721: 'c5wijlspqo',
#  722: 'berupaya',
#  723: 'kematian',
#  724: 'zixrbwliwz',
#  725: 'by',
#  726: 'kelamin',
#  727: 'n3metv2nw1',
#  728: 'basmi',
#  729: 'fogging',
#  730: 'malam',
#  731: 'mrhisyzjgo',
#  732: 'gigi',
#  733: 'rda4j5pwxi',
#  734: 'doktergigi',
#  735: 'doktergigiminim',
#  736: 'kotajayapura',
#  737: 'donor',
#  738: 'â·selasa',
#  739: '16',
#  740: 'â·pukul',
#  741: 'siang',
#  742: 'â·rsud',
#  743: 'â·',
#  744: 'jersey',
#  745: 'milan',
#  746: 'home',
#  747: 'â·cp',
#  748: 'yandrimilano',
#  749: 'cc',
#  750: '115milan',
#  751: 'selamat',
#  752: 'ulang',
#  753: 'se',
#  754: 'gratis',
#  755: 'tanjung',
#  756: 'ria',
#  757: 'mantri',
#  758: '45nj0kuqzh',
#  759: 'oyezxpxlfm',
#  760: 'men',
#  761: '6pylcquqxk',
#  762: 'masker',
#  763: 'wajib',
#  764: 'bukan',
#  765: 'yangâ\xa0sehat',
#  766: 'kbjxqh4i6s',
#  767: '0okc1b5dkh',
#  768: 'drs',
#  769: 'meninjau',
#  770: 'tipe',
#  771: 'c',
#  772: 'koyaâ\x80¦',
#  773: '7ht9i0nrkd',
#  774: 'banyak',
#  775: 'koperasi',
#  776: 'kenapa',
#  777: 'azfcrtux5h',
#  778: 'juni',
#  779: '2018',
#  780: 'tangani',
#  781: 'pg2stv6fis',
#  782: 'demamberdarah',
#  783: 'agen',
#  784: 'reseller',
#  785: 'essenzo',
#  786: 'bergamot',
#  787: 'essential',
#  788: 'oil',
#  789: 'atasi',
#  790: 'perut',
#  791: 'atau',
#  792: 'p',
#  793: 'kzhkdjynuf',
#  794: 'standar',
#  795: 'minimal',
#  796: 'i1vkc8fvwc',
#  797: 'vawdrvco61',
#  798: 'maiauna',
#  799: 'vfdswnthrsâ\xa0',
#  800: 'r0oahppp7x',
#  801: 'j2baip8orp',
#  802: 'rujukan',
#  803: 'full',
#  804: 'adaâ\xa0apa',
#  805: 'qtykhvh443',
#  806: 'kapolresta',
#  807: 'dampingi',
#  808: 'resmikan',
#  809: 'ramaela',
#  810: 'mooes4xzyl',
#  811: 'destro76293786',
#  812: 'dilanarya',
#  813: 'satriosoediro',
#  814: 'imanlagi',
#  815: 'gerindra',
#  816: 'itukan',
#  817: 'menurut',
#  818: 'lu',
#  819: 'adek',
#  820: 'gue',
#  821: 'kerja',
#  822: 'skrg',
#  823: 'bagiâ\x80¦',
#  824: 'zbqxddccg2',
#  825: 'satgas',
#  826: 'pamtas',
#  827: 'png',
#  828: 'teken',
#  829: 'mou',
#  830: 'gj5yuygugn',
#  831: 'mbrkn5wcjy'}

# %%
vocal = len(token.index_word)+1
vocal
# Out:
# 832

# %%
x = ['sakit kerjasama mou adek ']
token.texts_to_sequences(x)
# Out:
# [[13, 719, 829, 819]]

# %%
encode_text = token.texts_to_sequences(text)

# %%
max_kata = 100
X = pad_sequences(encode_text, maxlen = max_kata, padding = "post")

# %%
X
# Out:
# array([[ 23, 255,  50, ...,   0,   0,   0],
#        [259, 260, 261, ...,   0,   0,   0],
#        [  9,   4,   3, ...,   0,   0,   0],
#        ...,
#        [806, 807,  24, ...,   0,   0,   0],
#        [811, 812, 813, ...,   0,   0,   0],
#        [169,  31, 825, ...,   0,   0,   0]])

# %%
X_train, X_test, y_train, Y_test = train_test_split(X, y, random_state = 40, test_size = 0.3, stratify =y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-3638d65e1425> in <module>
# ----> 1 X_train, X_test, y_train, Y_test = train_test_split(X, y, random_state = 40, test_size = 0.3, stratify =y)
#
# NameError: name 'y' is not defined
