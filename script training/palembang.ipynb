# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
df = pd.read_csv("palembang.csv")
df.head()
# Out:
#                        created_at  ...                                           tweet_en
# 0  Fri Jan 27 14:55:22 +0000 2017  ...  Official Data of Puskesmas in Palembang City, ...
# 1  Mon Aug 11 07:57:11 +0000 2014  ...  Health Office urges merchants to sell healthy ...
# 2  Mon Jun 15 08:30:28 +0000 2020  ...  Residents in the Bumi Sako Damai complex in Pa...
# 3  Mon Mar 07 09:47:35 +0000 2016  ...  The last status in WA, a beautiful doctor from...
# 4  Fri Jun 21 12:27:10 +0000 2019  ...  Assalamu'alaikum SanakDulur DPPKB, Friday (21/...
#
# [5 rows x 3 columns]

# %%
def cleanTxt(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text)
    text = re.sub(r'#', '', text)
    text = re.sub(r'RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/\S+', '', text)
    
    return text

df['tweet_en'] = df['tweet_en'].apply(cleanTxt)
df['text'] = df['text'].apply(cleanTxt)
df
# Out:
#                          created_at  ...                                           tweet_en
# 0    Fri Jan 27 14:55:22 +0000 2017  ...  Official Data of Puskesmas in Palembang City, ...
# 1    Mon Aug 11 07:57:11 +0000 2014  ...  Health Office urges merchants to sell healthy ...
# 2    Mon Jun 15 08:30:28 +0000 2020  ...  Residents in the Bumi Sako Damai complex in Pa...
# 3    Mon Mar 07 09:47:35 +0000 2016  ...  The last status in WA, a beautiful doctor from...
# 4    Fri Jun 21 12:27:10 +0000 2019  ...  Assalamu'alaikum SanakDulur DPPKB, Friday (21/...
# ..                              ...  ...                                                ...
# 245  Mon Sep 07 09:00:04 +0000 2015  ...   Palembang City Is Proposed To Be A Healthy City
# 246  Mon Jul 11 09:09:00 +0000 2016  ...  Hospital in Palembang City Receives Bomb Terro...
# 247  Fri Feb 06 16:12:56 +0000 2015  ...  Palembang - Palembang is not yet a DHF outbrea...
# 248  Thu Jan 18 06:03:25 +0000 2018  ...  PindangPatin Palembang City Government of Sout...
# 249  Mon Sep 23 13:00:01 +0000 2019  ...  JKN-KIS Participants in Palembang City Translu...
#
# [250 rows x 3 columns]

# %%
#mendapatkan subjectivity dan polarity
def getSubjectivity(text):
    c = str(text)
    return TextBlob(c).sentiment.subjectivity

def getPolarity(text):
    c = str(text)
    return TextBlob(c).sentiment.polarity

df['Subjectivity'] = df['tweet_en'].apply(getSubjectivity)
df['Polarity'] = df['tweet_en'].apply(getPolarity)

# %%
df
# Out:
#                          created_at  ...  Polarity
# 0    Fri Jan 27 14:55:22 +0000 2017  ...  0.000000
# 1    Mon Aug 11 07:57:11 +0000 2014  ...  0.500000
# 2    Mon Jun 15 08:30:28 +0000 2020  ... -0.300000
# 3    Mon Mar 07 09:47:35 +0000 2016  ...  0.216667
# 4    Fri Jun 21 12:27:10 +0000 2019  ...  0.000000
# ..                              ...  ...       ...
# 245  Mon Sep 07 09:00:04 +0000 2015  ...  0.500000
# 246  Mon Jul 11 09:09:00 +0000 2016  ...  0.000000
# 247  Fri Feb 06 16:12:56 +0000 2015  ...  0.000000
# 248  Thu Jan 18 06:03:25 +0000 2018  ...  0.000000
# 249  Mon Sep 23 13:00:01 +0000 2019  ...  0.000000
#
# [250 rows x 5 columns]

# %%
#wordcloud
allwords = ' '.join([twts for twts in df['tweet_en']])
wordCloud = WordCloud(width = 500, height = 300, random_state = 21, max_font_size = 119).generate(allwords)

plt.imshow(wordCloud, interpolation = "bilinear")
plt.axis('off')
plt.show()

# %%
#mendapatkan nilai sentimen
def getAnalysis(score):
    if score < 0 :
        return 'Negative'
    elif score == 0 :
        return 'Neutral'
    else :
        return 'Positive'

df['Sentiment'] = df['Polarity'].apply(getAnalysis)

df
# Out:
#                          created_at  ... Sentiment
# 0    Fri Jan 27 14:55:22 +0000 2017  ...   Neutral
# 1    Mon Aug 11 07:57:11 +0000 2014  ...  Positive
# 2    Mon Jun 15 08:30:28 +0000 2020  ...  Negative
# 3    Mon Mar 07 09:47:35 +0000 2016  ...  Positive
# 4    Fri Jun 21 12:27:10 +0000 2019  ...   Neutral
# ..                              ...  ...       ...
# 245  Mon Sep 07 09:00:04 +0000 2015  ...  Positive
# 246  Mon Jul 11 09:09:00 +0000 2016  ...   Neutral
# 247  Fri Feb 06 16:12:56 +0000 2015  ...   Neutral
# 248  Thu Jan 18 06:03:25 +0000 2018  ...   Neutral
# 249  Mon Sep 23 13:00:01 +0000 2019  ...   Neutral
#
# [250 rows x 6 columns]

# %%
#plot the polarity and subjectivity
plt.figure(figsize =(8,6))
for i in range (0, df.shape[0]):
    plt.scatter(df['Polarity'][i], df['Subjectivity'][i], color = 'Blue')

plt.title("Sentiment Analysis Palembang")
plt.xlabel("Polarity")
plt.ylabel("Subjectivity")
plt.show()

# %%
#Plot the sentiment
df['Sentiment'].value_counts()

plt.title("Sentiment Analysis Palembang")
plt.xlabel("Sentiment")
plt.ylabel("Counts")
df['Sentiment'].value_counts().plot(kind = "bar")
plt.show()

# %%
df_final = df[['created_at', 'text', 'Subjectivity', 'Polarity', 'Sentiment']]
df_final
# Out:
#                          created_at  ... Sentiment
# 0    Fri Jan 27 14:55:22 +0000 2017  ...   Neutral
# 1    Mon Aug 11 07:57:11 +0000 2014  ...  Positive
# 2    Mon Jun 15 08:30:28 +0000 2020  ...  Negative
# 3    Mon Mar 07 09:47:35 +0000 2016  ...  Positive
# 4    Fri Jun 21 12:27:10 +0000 2019  ...   Neutral
# ..                              ...  ...       ...
# 245  Mon Sep 07 09:00:04 +0000 2015  ...  Positive
# 246  Mon Jul 11 09:09:00 +0000 2016  ...   Neutral
# 247  Fri Feb 06 16:12:56 +0000 2015  ...   Neutral
# 248  Thu Jan 18 06:03:25 +0000 2018  ...   Neutral
# 249  Mon Sep 23 13:00:01 +0000 2019  ...   Neutral
#
# [250 rows x 5 columns]

# %%
df_final.to_csv("sentiment_palembang.csv")
